# %% [markdown]
# <a href="https://colab.research.google.com/github/hvmt2003/Logistic-Regression/blob/main/Precision%2C_Recall%2C_F1_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/placement_cgpa_score_placed.csv')

# %%
dataset
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x=dataset.iloc[:,:-1]
y=dataset['placed']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score
cm=confusion_matrix(y_test,lr.predict(x_test))

# %%
cm
# Out:
# array([[10,  0],
#        [ 0, 10]])

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
precision_score(y_test,lr.predict(x_test))
# Out:
# 1.0

# %%
recall_score(y_test,lr.predict(x_test))
# Out:
# 1.0

# %%
f1_score(y_test,lr.predict(x_test))
# Out:
# 1.0
