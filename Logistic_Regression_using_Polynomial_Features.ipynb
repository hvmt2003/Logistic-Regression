# %% [markdown]
# <a href="https://colab.research.google.com/github/hvmt2003/Logistic-Regression/blob/main/Logistic_Regression_using_Polynomial_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Logistic Regression Without Polynomial Features**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/polynomial_logistic_50points.csv')

# %%
sns.scatterplot(x='data1',y='data2',data=df,hue='output')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df['output']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Logistic Regression with Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr1=LogisticRegression()

# %%
lr1.fit(x_train1,y_train1)
# Out:
# LogisticRegression()

# %%
lr1.score(x_test1,y_test1)
# Out:
# 0.8

# %%
x.shape
# Out:
# (50, 10)
